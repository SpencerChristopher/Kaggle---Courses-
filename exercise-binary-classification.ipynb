# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_27/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
# single config dictionary
cfg = {
    'hidden': {'units': 256, 'activation': 'relu'},
    'bn':     {},
    'drop':   {'rate': 0.3},
    'out':    {'units': 1, 'activation': 'sigmoid'}   # <- sigmoid for binary output
}

model = keras.Sequential([
    layers.Input(shape=input_shape),
    layers.BatchNormalization(**cfg['bn']),
    layers.Dense(**cfg['hidden']),

    layers.BatchNormalization(**cfg['bn']),
    layers.Dropout(**cfg['drop']),
    layers.Dense(**cfg['hidden']),

    layers.BatchNormalization(**cfg['bn']),
    layers.Dropout(**cfg['drop']),
    layers.Dense(**cfg['out'])
])

# Check your answer
q_1.check()
# Out:
# 2026-01-08 12:26:07.392909: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-08 12:26:07.393040: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-08 12:26:07.529730: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
cfg_opt = {
    'learning_rate': 0.001,      # default 0.001
    'beta_1': 0.9,
    'beta_2': 0.999,
    'epsilon': 1e-7
}

model.compile(
    optimizer=keras.optimizers.Adam(**cfg_opt),
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)
# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
    
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767875184.449598      67 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 175/175 [==============================] - 7s 8ms/step - loss: 0.4838 - binary_accuracy: 0.7704 - val_loss: 0.4317 - val_binary_accuracy: 0.8030
# Epoch 2/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4251 - binary_accuracy: 0.7999 - val_loss: 0.4035 - val_binary_accuracy: 0.8090
# Epoch 3/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4102 - binary_accuracy: 0.8073 - val_loss: 0.3941 - val_binary_accuracy: 0.8158
# Epoch 4/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4022 - binary_accuracy: 0.8130 - val_loss: 0.3908 - val_binary_accuracy: 0.8164
# Epoch 5/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3987 - binary_accuracy: 0.8140 - val_loss: 0.3854 - val_binary_accuracy: 0.8216
# Epoch 6/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3929 - binary_accuracy: 0.8171 - val_loss: 0.3813 - val_binary_accuracy: 0.8239
# Epoch 7/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3900 - binary_accuracy: 0.8184 - val_loss: 0.3811 - val_binary_accuracy: 0.8241
# Epoch 8/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3868 - binary_accuracy: 0.8205 - val_loss: 0.3782 - val_binary_accuracy: 0.8264
# Epoch 9/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3833 - binary_accuracy: 0.8218 - val_loss: 0.3730 - val_binary_accuracy: 0.8275
# Epoch 10/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3797 - binary_accuracy: 0.8244 - val_loss: 0.3719 - val_binary_accuracy: 0.8291
# Epoch 11/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3779 - binary_accuracy: 0.8249 - val_loss: 0.3699 - val_binary_accuracy: 0.8311
# Epoch 12/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3754 - binary_accuracy: 0.8267 - val_loss: 0.3675 - val_binary_accuracy: 0.8320
# Epoch 13/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3724 - binary_accuracy: 0.8273 - val_loss: 0.3694 - val_binary_accuracy: 0.8336
# Epoch 14/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3706 - binary_accuracy: 0.8298 - val_loss: 0.3649 - val_binary_accuracy: 0.8331
# Epoch 15/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3690 - binary_accuracy: 0.8292 - val_loss: 0.3693 - val_binary_accuracy: 0.8312
# Epoch 16/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3670 - binary_accuracy: 0.8298 - val_loss: 0.3623 - val_binary_accuracy: 0.8343
# Epoch 17/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3642 - binary_accuracy: 0.8324 - val_loss: 0.3599 - val_binary_accuracy: 0.8352
# Epoch 18/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3626 - binary_accuracy: 0.8325 - val_loss: 0.3585 - val_binary_accuracy: 0.8359
# Epoch 19/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3619 - binary_accuracy: 0.8330 - val_loss: 0.3573 - val_binary_accuracy: 0.8377
# Epoch 20/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3597 - binary_accuracy: 0.8342 - val_loss: 0.3589 - val_binary_accuracy: 0.8372
# Epoch 21/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3581 - binary_accuracy: 0.8353 - val_loss: 0.3583 - val_binary_accuracy: 0.8375
# Epoch 22/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3574 - binary_accuracy: 0.8338 - val_loss: 0.3572 - val_binary_accuracy: 0.8367
# Epoch 23/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3555 - binary_accuracy: 0.8356 - val_loss: 0.3557 - val_binary_accuracy: 0.8389
# Epoch 24/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3550 - binary_accuracy: 0.8350 - val_loss: 0.3548 - val_binary_accuracy: 0.8387
# Epoch 25/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3540 - binary_accuracy: 0.8358 - val_loss: 0.3553 - val_binary_accuracy: 0.8380
# Epoch 26/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3519 - binary_accuracy: 0.8360 - val_loss: 0.3524 - val_binary_accuracy: 0.8407
# Epoch 27/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3515 - binary_accuracy: 0.8378 - val_loss: 0.3537 - val_binary_accuracy: 0.8400
# Epoch 28/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3504 - binary_accuracy: 0.8389 - val_loss: 0.3534 - val_binary_accuracy: 0.8400
# Epoch 29/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3486 - binary_accuracy: 0.8389 - val_loss: 0.3519 - val_binary_accuracy: 0.8409
# Epoch 30/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3479 - binary_accuracy: 0.8391 - val_loss: 0.3514 - val_binary_accuracy: 0.8397
# Epoch 31/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3477 - binary_accuracy: 0.8401 - val_loss: 0.3523 - val_binary_accuracy: 0.8407
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
